# %% [markdown]
# ## Session 3 - Descriptive Statistics
# The descriptive Statistics It is a great way to start exploring data and helps identify patterns of behavior.

# %%
import pandas as pd
import numpy as np

# %%
data = [10, 24, 7, 89, 99, 7, 15, 7]
mean = np.mean(data)
# print(mean)
mean
# Out:
# np.float64(32.25)

# %%
# Variance
variance = np.var(data)
variance
# Out:
# np.float64(1306.1875)

# %%
median = np.median(data)
median
# Out:
# np.float64(24.0)

# %%
# Mode
from scipy import stats

mode = stats.mode(data)
mode
# Out:
# ModeResult(mode=np.int64(7), count=np.int64(3))

# %%
# Out:
# np.float64(1306.1875)

# %%
# Load data
data_csv = pd.read_csv('../s2/data/percent_bachelors_degrees_women_usa.csv', delimiter=',')
data_csv.head(5)
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology  Business  \
# 0  1970          NaN     11.921005                 59.7  29.088363  9.064439
# 1  1970          NaN     11.921005                 59.7  29.088363  9.064439
# 2  1970          NaN     11.921005                 59.7  29.088363  9.064439
# 3  1970          NaN     11.921005                 59.7  29.088363  9.064439
# 4  1970          NaN     11.921005                 59.7  29.088363  9.064439
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.3              13.6  74.535328          0.8
# 2                           35.3              13.6  74.535328          0.8
# 3                           35.3              13.6  74.535328          0.8
# 4                           35.3              13.6  74.535328          0.8
#
# ...

# %%
data_csv.describe()
# Out:
#               Year  Agriculture  Architecture  Art and Performance    Biology  \
# count    49.000000    44.000000     49.000000            49.000000  49.000000
# mean   1987.632653    32.585262     30.581347            60.912245  46.542672
# std      13.377054    13.581690     11.718188             1.293354  11.746593
# min    1970.000000     5.452797     11.921005            58.600000  29.088363
# 25%    1975.000000    29.011572     19.134048            59.700000  34.449902
# 50%    1987.000000    32.670054     35.453083            61.000000  50.099811
# 75%    1999.000000    45.259829     40.023585            61.900000  58.228823
# max    2011.000000    50.037182     44.499331            63.400000  62.169456
#
#         Business  Communications and Journalism  Computer Science  Education  \
# count  49.000000                      49.000000         49.000000  49.000000
# mean   36.167614                      53.240816         24.065306  76.072466
# ...

# %%
print(data_csv['Year'].mean())
print(data_csv['Year'].std())
print(data_csv['Year'].min())
print(data_csv['Year'].quantile(0.25))
print(data_csv['Year'].quantile(0.50))
print(data_csv['Year'].quantile(0.75))
print(data_csv['Year'].max())
# Out:
# 1987.6326530612246
# 13.37705416866107
# 1970
# 1975.0
# 1987.0
# 1999.0
# 2011
